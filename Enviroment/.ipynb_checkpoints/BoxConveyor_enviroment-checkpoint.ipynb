# %% [markdown]
# # 1 - Importa bibliotecas

# %%
import os
import gym
import numpy as np
import torch as th
import websocket
import json
import time
import random
import psutil

# %% [markdown]
# # 2 - Cria funções de encoding/decoding em json

# %%
class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)                
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        return json.JSONEncoder.default(self, obj)
    
def encode_json(identifier, reward, done, states):
    data = {}
    data['identifier'] = identifier
    data['reward'] = reward
    data['done'] = done
    data['states'] = states
    json_data = json.dumps(data, cls=NumpyEncoder)       
    return json_data

# %%
def enviroment(data, reward, done,step, CountCan,correctCan, ConveyorPosition, Forward, Backward, RobotCycle, StartCycle, arrayPosicoes, ToDropCan):
        step += 1
        message = ''
        BoxCompleted = False
        Can = False
        SensorHandling = False
        SensorRobot = False
        CanDropped = False
        
        #print(data)
        
        if data['actions'][0] == 0:
            Forward = False
            Backward = False
            
        if data['actions'][0] == 1:
            Forward = True
            Backward = False
                       
        if data['actions'][0] == 2:
            Backward = True
            Forward = False
        
        reward = 0
            
        if Forward:
            ConveyorPosition = ConveyorPosition + 100 
            
        if Backward:
            ConveyorPosition = ConveyorPosition - 100
            
        if ConveyorPosition < 20 and RobotCycle == 0:
            SensorRobot = True 
        if ConveyorPosition > 342 and ConveyorPosition < 700:
            SensorHandling = True
        if ConveyorPosition < 342 and ConveyorPosition > 700:
            SensorHandling = False
        
        if correctCan == 9:
            BoxCompleted == True
            #print('--- passo: ', step, 'posicoes de lata: ', arrayPosicoes)
        if correctCan != 9: 
            BoxCompleted == False
            
        if  SensorHandling and not BoxCompleted and not Forward and not Backward:            
            CountCan += 1
            arrayPosicoes.append(ConveyorPosition)
            CanDropped = True
            if CountCan % 3 == 0:
                Can = True
                
            
            
#             if ToDropCan == 1:
#                 CountCan += 1                
                 
                
#             if ToDropCan == 0:
#                 Can = False
#                 ToDropCan += 1
#             if Can:
#                 ToDropCan = 0
                

            
                
                
            
            
        if ConveyorPosition > 579 and ConveyorPosition < 601 and CountCan < 10 and CountCan > 6 and CanDropped:
            reward = 300 - step/5
            correctCan += 1
        if ConveyorPosition > 479 and ConveyorPosition < 501 and CountCan < 7 and CountCan > 3 and CanDropped:
            reward = 200 - step/5
            correctCan += 1
        if ConveyorPosition > 379 and ConveyorPosition < 401 and CountCan < 4 and CanDropped:
            reward = 100 - step/5
            correctCan += 1
            
            
        
        if RobotCycle > 0:
            if RobotCycle > 1:
                reward = 1000 + (correctCan*1000)
                print('-------------------Aguardando!------------------------- passo: ', step)
            if RobotCycle == 1:
                done = True
                reward = 10000 + (correctCan  * 7000) - step
                print('-------------------Ciclo completo!------------------------- passo: ', step)
            RobotCycle -= 1 
        
        if RobotCycle < 3 and RobotCycle > 0:
            SensorRobot = False
        
        if SensorRobot and StartCycle:
            RobotCycle = random.randint(3, 5)
            StartCycle = False
            reward = 1000 + (correctCan  * 150)
            CountCan == 0
            print('Aguardando descarga------------')
        if ConveyorPosition > 0 and correctCan == 9 and Backward:
            reward = (correctCan * 120)  - (ConveyorPosition/8)                
            print('<<<<<----- voltando ---<<<<<    posicao: ',ConveyorPosition,' numero de latas corretas: ', correctCan, ' recompensa: ',reward, )
        
        if ConveyorPosition < 20 and ConveyorPosition > -1 and correctCan == 9 and not StartCycle and not Forward and not Backward:
            reward = 5000 + (correctCan * 2000) 
            SensorRobot = True
            StartCycle = True
            print('@@@@@-------pronto a descarregar!@@@@')
                
            
            
        
        #if CountCan > 9:
            #reward = 100 - (step *(11 - CountCan))
            #if CountCan > 12:
                #done = True
        
            
        #if ConveyorPosition < 0:
            #reward = ConveyorPosition*10
            
        if ConveyorPosition < -200 or ConveyorPosition > 800:
            done = True
        
        if reward > 90 and not Backward and not Forward:
            print('passo: ',step,' recompensa: ',reward, ' posicoes de lata: ', arrayPosicoes,' posicao: ', ConveyorPosition )
            
        states = [Can, SensorHandling, SensorRobot, round((ConveyorPosition/600),2)]
        if CountCan > 15:
            pass
            #done = True
            
        if step > 500:            
            done = True
        
        message = encode_json('BoxConveyor', reward, done, states)    
        return message, reward, done,step, CountCan,correctCan, ConveyorPosition, Forward, Backward, RobotCycle, StartCycle, arrayPosicoes, ToDropCan

# %% [markdown]
# # 4 - Verifica se o servidor socket está ativo

# %%
server_found = False

for conn in psutil.net_connections():
    if conn.laddr.port == 12000 and conn.status == 'LISTEN':
        print("Um servidor socket está sendo executado na porta 12000.")
        server_found = True

if not server_found:
    print("Nenhum servidor socket está sendo executado na porta 12000.")
# Out:
# Um servidor socket está sendo executado na porta 12000.

# %% [markdown]
# # 5 - Ativa o ambiente para treino

# %%
ws = websocket.WebSocket()
ws.connect("ws://127.0.0.2:12000")
time.sleep(1)
reward = 0
done = False
CountCan = 0
ConveyorPosition = 0
Forward = False
Backward = False
StartCycle = False
step = 0
RobotCycle = 0
message = ''
arrayPosicoes = []
ToDropCan = 0
correctCan = 0

while True:
    data =''
    data = json.loads(ws.recv())
    if data['identifier']  == 'BoxConveyor_manual':
        message, reward, done,step, CountCan,correctCan, ConveyorPosition, Forward, Backward, RobotCycle, StartCycle, arrayPosicoes, ToDropCan = enviroment(data, reward, done, step, CountCan, correctCan,ConveyorPosition, Forward, Backward,RobotCycle,StartCycle, arrayPosicoes, ToDropCan) 
        ws.send(message)
        if done:
            done = False
            reward = 0
            step = 0
            CountCan = 0
            ConveyorPosition = 0
            Forward = False
            Backward = False
            RobotCycle = 0
            StartCycle = False
            arrayPosicoes = []
            ToDropCan =0
            correctCan = 0
# Out:
# passo:  23  recompensa:  95.4  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [500, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [500, 400, 400]  posicao:  400
# passo:  15  recompensa:  197.0  posicoes de lata:  [500, 400, 400, 500]  posicao:  500
# passo:  16  recompensa:  196.8  posicoes de lata:  [500, 400, 400, 500, 500]  posicao:  500
# passo:  21  recompensa:  295.8  posicoes de lata:  [500, 400, 400, 500, 500, 400, 600]  posicao:  600
# passo:  72  recompensa:  185.6  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  80  recompensa:  284.0  posicoes de lata:  [400, 400, 500, 500, 600, 600, 600]  posicao:  600
# passo:  85  recompensa:  283.0  posicoes de lata:  [400, 400, 500, 500, 600, 600, 600, 600]  posicao:  600
# passo:  88  recompensa:  282.4  posicoes de lata:  [400, 400, 500, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400, 600, 400]  posicao:  400
# passo:  26  recompensa:  194.8  posicoes de lata:  [400, 600, 400, 400, 400, 500]  posicao:  500
# passo:  28  recompensa:  294.4  posicoes de lata:  [400, 600, 400, 400, 400, 500, 600]  posicao:  600
# passo:  25  recompensa:  95.0  posicoes de lata:  [400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  41  recompensa:  91.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  43  recompensa:  191.4  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  47  recompensa:  290.6  posicoes de lata:  [400, 400, 400, 500, 600, 600, 600]  posicao:  600
# passo:  50  recompensa:  290.0  posicoes de lata:  [400, 400, 400, 500, 600, 600, 600, 600]  posicao:  600
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  20  recompensa:  96.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  29  recompensa:  94.2  posicoes de lata:  [400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400]  posicao:  400
# passo:  38  recompensa:  92.4  posicoes de lata:  [400, 500, 400]  posicao:  400
# passo:  43  recompensa:  191.4  posicoes de lata:  [400, 500, 400, 400, 500]  posicao:  500
# passo:  44  recompensa:  191.2  posicoes de lata:  [400, 500, 400, 400, 500, 500]  posicao:  500
# passo:  49  recompensa:  290.2  posicoes de lata:  [400, 500, 400, 400, 500, 500, 500, 600]  posicao:  600
# passo:  50  recompensa:  290.0  posicoes de lata:  [400, 500, 400, 400, 500, 500, 500, 600, 600]  posicao:  600
# passo:  14  recompensa:  97.2  posicoes de lata:  [400]  posicao:  400
# passo:  20  recompensa:  196.0  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  21  recompensa:  195.8  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  24  recompensa:  195.2  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  45  recompensa:  291.0  posicoes de lata:  [400, 500, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  48  recompensa:  290.4  posicoes de lata:  [400, 500, 500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  33  recompensa:  93.4  posicoes de lata:  [400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  39  recompensa:  92.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  31  recompensa:  293.8  posicoes de lata:  [400, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  32  recompensa:  293.6  posicoes de lata:  [400, 600, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  33  recompensa:  293.4  posicoes de lata:  [400, 600, 600, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  28  recompensa:  194.4  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  29  recompensa:  194.2  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  17  recompensa:  96.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  24  recompensa:  195.2  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  30  recompensa:  94.0  posicoes de lata:  [400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  29  recompensa:  194.2  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  33  recompensa:  193.4  posicoes de lata:  [400, 400, 400, 500, 400, 500]  posicao:  500
# passo:  35  recompensa:  293.0  posicoes de lata:  [400, 400, 400, 500, 400, 500, 600]  posicao:  600
# passo:  36  recompensa:  292.8  posicoes de lata:  [400, 400, 400, 500, 400, 500, 600, 600]  posicao:  600
# passo:  39  recompensa:  92.2  posicoes de lata:  [400]  posicao:  400
# passo:  40  recompensa:  92.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  41  recompensa:  91.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  20  recompensa:  96.0  posicoes de lata:  [500, 500, 400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400]  posicao:  400
# passo:  36  recompensa:  92.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  44  recompensa:  91.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  53  recompensa:  189.4  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  17  recompensa:  196.6  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  18  recompensa:  196.4  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  19  recompensa:  196.2  posicoes de lata:  [500, 500, 500, 500, 500, 500]  posicao:  500
# passo:  70  recompensa:  286.0  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600]  posicao:  600
# passo:  71  recompensa:  285.8  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  72  recompensa:  285.6  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  36  recompensa:  92.8  posicoes de lata:  [400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  41  recompensa:  191.8  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  20  recompensa:  96.0  posicoes de lata:  [400, 500, 400]  posicao:  400
# passo:  44  recompensa:  191.2  posicoes de lata:  [400, 500, 400, 600, 600, 500]  posicao:  500
# passo:  46  recompensa:  290.8  posicoes de lata:  [400, 500, 400, 600, 600, 500, 600]  posicao:  600
# passo:  105  recompensa:  279.0  posicoes de lata:  [500, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  110  recompensa:  278.0  posicoes de lata:  [500, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  111  recompensa:  277.8  posicoes de lata:  [500, 500, 600, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  27  recompensa:  294.6  posicoes de lata:  [400, 500, 600, 600, 600, 600, 500, 500, 600]  posicao:  600
# passo:  29  recompensa:  94.2  posicoes de lata:  [400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  16  recompensa:  196.8  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  17  recompensa:  196.6  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  18  recompensa:  196.4  posicoes de lata:  [400, 400, 500, 500, 500, 500]  posicao:  500
# passo:  23  recompensa:  295.4  posicoes de lata:  [400, 400, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  26  recompensa:  294.8  posicoes de lata:  [400, 400, 500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  24  recompensa:  95.2  posicoes de lata:  [400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  28  recompensa:  194.4  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  10  recompensa:  98.0  posicoes de lata:  [400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  33  recompensa:  93.4  posicoes de lata:  [400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  24  recompensa:  95.2  posicoes de lata:  [400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400]  posicao:  400
# passo:  28  recompensa:  94.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  29  recompensa:  94.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  32  recompensa:  193.6  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  33  recompensa:  193.4  posicoes de lata:  [400, 400, 400, 400, 500, 500]  posicao:  500
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  31  recompensa:  193.8  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  32  recompensa:  193.6  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  40  recompensa:  292.0  posicoes de lata:  [400, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  36  recompensa:  92.8  posicoes de lata:  [400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  51  recompensa:  289.8  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600]  posicao:  600
# passo:  52  recompensa:  289.6  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  26  recompensa:  194.8  posicoes de lata:  [400, 600, 600, 600, 500]  posicao:  500
# passo:  68  recompensa:  186.4  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  69  recompensa:  186.2  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  22  recompensa:  195.6  posicoes de lata:  [400, 400, 600, 600, 500]  posicao:  500
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  28  recompensa:  294.4  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600]  posicao:  600
# passo:  29  recompensa:  294.2  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  30  recompensa:  294.0  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  38  recompensa:  92.4  posicoes de lata:  [400]  posicao:  400
# passo:  39  recompensa:  92.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  42  recompensa:  191.6  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  43  recompensa:  191.4  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  44  recompensa:  191.2  posicoes de lata:  [400, 400, 500, 500, 500, 500]  posicao:  500
# passo:  24  recompensa:  95.2  posicoes de lata:  [400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  40  recompensa:  92.0  posicoes de lata:  [400]  posicao:  400
# passo:  41  recompensa:  91.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  42  recompensa:  91.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  36  recompensa:  92.8  posicoes de lata:  [400]  posicao:  400
# passo:  42  recompensa:  91.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  47  recompensa:  90.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  52  recompensa:  189.6  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  57  recompensa:  288.6  posicoes de lata:  [400, 400, 400, 400, 500, 400, 600]  posicao:  600
# passo:  58  recompensa:  288.4  posicoes de lata:  [400, 400, 400, 400, 500, 400, 600, 600]  posicao:  600
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  22  recompensa:  295.6  posicoes de lata:  [400, 400, 500, 400, 400, 600, 600]  posicao:  600
# passo:  23  recompensa:  295.4  posicoes de lata:  [400, 400, 500, 400, 400, 600, 600, 600]  posicao:  600
# passo:  24  recompensa:  295.2  posicoes de lata:  [400, 400, 500, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  33  recompensa:  93.4  posicoes de lata:  [400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400]  posicao:  400
# passo:  32  recompensa:  93.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  35  recompensa:  193.0  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  36  recompensa:  192.8  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  39  recompensa:  292.2  posicoes de lata:  [400, 400, 500, 500, 500, 600, 600]  posicao:  600
# passo:  40  recompensa:  292.0  posicoes de lata:  [400, 400, 500, 500, 500, 600, 600, 600]  posicao:  600
# passo:  35  recompensa:  93.0  posicoes de lata:  [400]  posicao:  400
# passo:  36  recompensa:  92.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  41  recompensa:  191.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  10  recompensa:  98.0  posicoes de lata:  [400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  17  recompensa:  96.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  25  recompensa:  195.0  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  28  recompensa:  294.4  posicoes de lata:  [400, 400, 400, 400, 500, 600, 600]  posicao:  600
# passo:  31  recompensa:  93.8  posicoes de lata:  [500, 500, 400]  posicao:  400
# passo:  40  recompensa:  192.0  posicoes de lata:  [500, 500, 400, 400, 500]  posicao:  500
# passo:  41  recompensa:  191.8  posicoes de lata:  [500, 500, 400, 400, 500, 500]  posicao:  500
# passo:  44  recompensa:  291.2  posicoes de lata:  [500, 500, 400, 400, 500, 500, 500, 600]  posicao:  600
# passo:  45  recompensa:  291.0  posicoes de lata:  [500, 500, 400, 400, 500, 500, 500, 600, 600]  posicao:  600
# passo:  39  recompensa:  92.2  posicoes de lata:  [400]  posicao:  400
# passo:  40  recompensa:  92.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  41  recompensa:  91.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  43  recompensa:  191.4  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  47  recompensa:  290.6  posicoes de lata:  [400, 400, 400, 500, 600, 600, 600]  posicao:  600
# passo:  48  recompensa:  290.4  posicoes de lata:  [400, 400, 400, 500, 600, 600, 600, 600]  posicao:  600
# passo:  49  recompensa:  290.2  posicoes de lata:  [400, 400, 400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  21  recompensa:  195.8  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  22  recompensa:  195.6  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  23  recompensa:  195.4  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  25  recompensa:  295.0  posicoes de lata:  [400, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  26  recompensa:  294.8  posicoes de lata:  [400, 500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  27  recompensa:  294.6  posicoes de lata:  [400, 500, 500, 500, 500, 500, 600, 600, 600]  posicao:  600
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  24  recompensa:  195.2  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  38  recompensa:  92.4  posicoes de lata:  [400]  posicao:  400
# passo:  42  recompensa:  91.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  45  recompensa:  91.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  20  recompensa:  96.0  posicoes de lata:  [500, 400]  posicao:  400
# passo:  21  recompensa:  95.8  posicoes de lata:  [500, 400, 400]  posicao:  400
# passo:  27  recompensa:  294.6  posicoes de lata:  [500, 400, 400, 400, 400, 400, 600]  posicao:  600
# passo:  34  recompensa:  293.2  posicoes de lata:  [500, 400, 400, 400, 400, 400, 600, 600]  posicao:  600
# passo:  35  recompensa:  293.0  posicoes de lata:  [500, 400, 400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  27  recompensa:  94.6  posicoes de lata:  [400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  33  recompensa:  93.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  88  recompensa:  282.4  posicoes de lata:  [400, 400, 400, 400, 400, 400, 400, 400, 600]  posicao:  600
# passo:  33  recompensa:  93.4  posicoes de lata:  [400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400]  posicao:  400
# passo:  72  recompensa:  185.6  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  17  recompensa:  96.6  posicoes de lata:  [400]  posicao:  400
# passo:  33  recompensa:  193.4  posicoes de lata:  [400, 500, 600, 600, 600, 500]  posicao:  500
# passo:  40  recompensa:  292.0  posicoes de lata:  [400, 500, 600, 600, 600, 500, 500, 600]  posicao:  600
# passo:  41  recompensa:  291.8  posicoes de lata:  [400, 500, 600, 600, 600, 500, 500, 600, 600]  posicao:  600
# passo:  26  recompensa:  94.8  posicoes de lata:  [400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  32  recompensa:  93.6  posicoes de lata:  [500, 500, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  22  recompensa:  295.6  posicoes de lata:  [400, 400, 400, 400, 400, 400, 500, 600]  posicao:  600
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  26  recompensa:  194.8  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  29  recompensa:  194.2  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  30  recompensa:  194.0  posicoes de lata:  [400, 400, 500, 500, 500, 500]  posicao:  500
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  13  recompensa:  197.4  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  7  recompensa:  98.6  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  195.6  posicoes de lata:  [400, 500, 500, 400, 400, 500]  posicao:  500
# passo:  25  recompensa:  95.0  posicoes de lata:  [400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  30  recompensa:  194.0  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  31  recompensa:  193.8  posicoes de lata:  [400, 400, 400, 400, 500, 500]  posicao:  500
# passo:  15  recompensa:  97.0  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  25  recompensa:  195.0  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  26  recompensa:  194.8  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  27  recompensa:  194.6  posicoes de lata:  [400, 400, 400, 500, 500, 500]  posicao:  500
# passo:  10  recompensa:  98.0  posicoes de lata:  [400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  16  recompensa:  196.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  21  recompensa:  95.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  26  recompensa:  194.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  29  recompensa:  294.2  posicoes de lata:  [400, 400, 400, 400, 400, 500, 500, 600]  posicao:  600
# passo:  30  recompensa:  294.0  posicoes de lata:  [400, 400, 400, 400, 400, 500, 500, 600, 600]  posicao:  600
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 500, 400]  posicao:  400
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  39  recompensa:  292.2  posicoes de lata:  [600, 500, 500, 600, 600, 600, 600]  posicao:  600
# passo:  40  recompensa:  292.0  posicoes de lata:  [600, 500, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  41  recompensa:  291.8  posicoes de lata:  [600, 500, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  6  recompensa:  98.8  posicoes de lata:  [400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 600, 400]  posicao:  400
# passo:  26  recompensa:  194.8  posicoes de lata:  [500, 600, 600, 600, 500]  posicao:  500
# passo:  27  recompensa:  194.6  posicoes de lata:  [500, 600, 600, 600, 500, 500]  posicao:  500
# passo:  29  recompensa:  294.2  posicoes de lata:  [500, 600, 600, 600, 500, 500, 600]  posicao:  600
# passo:  30  recompensa:  294.0  posicoes de lata:  [500, 600, 600, 600, 500, 500, 600, 600]  posicao:  600
# passo:  33  recompensa:  293.4  posicoes de lata:  [500, 600, 600, 600, 500, 500, 600, 600, 600]  posicao:  600
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  28  recompensa:  194.4  posicoes de lata:  [400, 600, 600, 600, 600, 500]  posicao:  500
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  296.2  posicoes de lata:  [400, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  24  recompensa:  295.2  posicoes de lata:  [400, 600, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [500, 500, 400]  posicao:  400
# passo:  6  recompensa:  98.8  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  198.0  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  8  recompensa:  98.4  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  7  recompensa:  98.6  posicoes de lata:  [400]  posicao:  400
# passo:  8  recompensa:  98.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  9  recompensa:  98.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  13  recompensa:  197.4  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  14  recompensa:  197.2  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  15  recompensa:  197.0  posicoes de lata:  [400, 400, 400, 500, 500, 500]  posicao:  500
# passo:  21  recompensa:  295.8  posicoes de lata:  [400, 400, 400, 500, 500, 500, 600]  posicao:  600
# passo:  22  recompensa:  295.6  posicoes de lata:  [400, 400, 400, 500, 500, 500, 600, 600]  posicao:  600
# passo:  23  recompensa:  295.4  posicoes de lata:  [400, 400, 400, 500, 500, 500, 600, 600, 600]  posicao:  600
# <<<<<----- voltando ---<<<<<    posicao:  600  numero de latas corretas:  9  recompensa:  1005.0
# <<<<<----- voltando ---<<<<<    posicao:  500  numero de latas corretas:  9  recompensa:  1017.5
# <<<<<----- voltando ---<<<<<    posicao:  400  numero de latas corretas:  9  recompensa:  1030.0
# <<<<<----- voltando ---<<<<<    posicao:  600  numero de latas corretas:  9  recompensa:  1005.0
# <<<<<----- voltando ---<<<<<    posicao:  500  numero de latas corretas:  9  recompensa:  1017.5
# <<<<<----- voltando ---<<<<<    posicao:  400  numero de latas corretas:  9  recompensa:  1030.0
# <<<<<----- voltando ---<<<<<    posicao:  300  numero de latas corretas:  9  recompensa:  1042.5
# <<<<<----- voltando ---<<<<<    posicao:  300  numero de latas corretas:  9  recompensa:  1042.5
# <<<<<----- voltando ---<<<<<    posicao:  300  numero de latas corretas:  9  recompensa:  1042.5
# <<<<<----- voltando ---<<<<<    posicao:  200  numero de latas corretas:  9  recompensa:  1055.0
# <<<<<----- voltando ---<<<<<    posicao:  300  numero de latas corretas:  9  recompensa:  1042.5
# <<<<<----- voltando ---<<<<<    posicao:  400  numero de latas corretas:  9  recompensa:  1030.0
# <<<<<----- voltando ---<<<<<    posicao:  300  numero de latas corretas:  9  recompensa:  1042.5
# <<<<<----- voltando ---<<<<<    posicao:  400  numero de latas corretas:  9  recompensa:  1030.0
# <<<<<----- voltando ---<<<<<    posicao:  500  numero de latas corretas:  9  recompensa:  1017.5
# <<<<<----- voltando ---<<<<<    posicao:  400  numero de latas corretas:  9  recompensa:  1030.0
# <<<<<----- voltando ---<<<<<    posicao:  300  numero de latas corretas:  9  recompensa:  1042.5
# <<<<<----- voltando ---<<<<<    posicao:  200  numero de latas corretas:  9  recompensa:  1055.0
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  200  numero de latas corretas:  9  recompensa:  1055.0
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  200  numero de latas corretas:  9  recompensa:  1055.0
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# <<<<<----- voltando ---<<<<<    posicao:  200  numero de latas corretas:  9  recompensa:  1055.0
# <<<<<----- voltando ---<<<<<    posicao:  100  numero de latas corretas:  9  recompensa:  1067.5
# @@@@@-------pronto a descarregar!@@@@
# passo:  141  recompensa:  23000  posicoes de lata:  [400, 400, 400, 500, 500, 500, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 400, 400, 500, 600, 600, 600, 600, 600, 600, 600, 600, 400, 400, 400, 400, 400, 400, 400, 400, 400, 500, 500, 500, 600, 600]  posicao:  0
# Aguardando descarga------------
# @@@@@-------pronto a descarregar!@@@@
# passo:  142  recompensa:  23000  posicoes de lata:  [400, 400, 400, 500, 500, 500, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 600, 400, 400, 500, 600, 600, 600, 600, 600, 600, 600, 600, 400, 400, 400, 400, 400, 400, 400, 400, 400, 500, 500, 500, 600, 600]  posicao:  0
# -------------------Aguardando!------------------------- passo:  143
# -------------------Aguardando!------------------------- passo:  144
# -------------------Ciclo completo!------------------------- passo:  145
# passo:  26  recompensa:  94.8  posicoes de lata:  [400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  28  recompensa:  94.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  32  recompensa:  93.6  posicoes de lata:  [400]  posicao:  400
# passo:  33  recompensa:  93.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  168  recompensa:  166.4  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  172  recompensa:  265.6  posicoes de lata:  [400, 400, 400, 400, 400, 500, 500, 500, 600]  posicao:  600
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  20  recompensa:  96.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  38  recompensa:  192.4  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  39  recompensa:  192.2  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  40  recompensa:  192.0  posicoes de lata:  [400, 400, 500, 500, 500, 500]  posicao:  500
# passo:  27  recompensa:  94.6  posicoes de lata:  [400]  posicao:  400
# passo:  35  recompensa:  193.0  posicoes de lata:  [400, 500, 600, 600, 600, 500]  posicao:  500
# passo:  54  recompensa:  189.2  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  55  recompensa:  189.0  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  58  recompensa:  288.4  posicoes de lata:  [500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  59  recompensa:  288.2  posicoes de lata:  [500, 500, 500, 500, 500, 600, 600, 600]  posicao:  600
# passo:  60  recompensa:  288.0  posicoes de lata:  [500, 500, 500, 500, 500, 600, 600, 600, 600]  posicao:  600
# passo:  45  recompensa:  91.0  posicoes de lata:  [400]  posicao:  400
# passo:  46  recompensa:  90.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  47  recompensa:  90.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  39  recompensa:  192.2  posicoes de lata:  [600, 600, 600, 600, 500]  posicao:  500
# passo:  40  recompensa:  192.0  posicoes de lata:  [600, 600, 600, 600, 500, 500]  posicao:  500
# passo:  61  recompensa:  187.8  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  62  recompensa:  187.6  posicoes de lata:  [400, 400, 400, 400, 500, 500]  posicao:  500
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  21  recompensa:  195.8  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  17  recompensa:  96.6  posicoes de lata:  [400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  296.2  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  20  recompensa:  296.0  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  21  recompensa:  295.8  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  38  recompensa:  92.4  posicoes de lata:  [400, 500, 400]  posicao:  400
# passo:  40  recompensa:  192.0  posicoes de lata:  [400, 500, 400, 500]  posicao:  500
# passo:  41  recompensa:  191.8  posicoes de lata:  [400, 500, 400, 500, 500]  posicao:  500
# passo:  42  recompensa:  191.6  posicoes de lata:  [400, 500, 400, 500, 500, 500]  posicao:  500
# passo:  48  recompensa:  290.4  posicoes de lata:  [400, 500, 400, 500, 500, 500, 500, 400, 600]  posicao:  600
# passo:  14  recompensa:  97.2  posicoes de lata:  [400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400]  posicao:  400
# passo:  40  recompensa:  92.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  43  recompensa:  191.4  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  69  recompensa:  186.2  posicoes de lata:  [400, 400, 500, 500, 600, 500]  posicao:  500
# passo:  70  recompensa:  186.0  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  71  recompensa:  185.8  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  72  recompensa:  185.6  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  62  recompensa:  187.6  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  63  recompensa:  187.4  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  38  recompensa:  92.4  posicoes de lata:  [400]  posicao:  400
# passo:  39  recompensa:  92.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  42  recompensa:  191.6  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  43  recompensa:  191.4  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  44  recompensa:  191.2  posicoes de lata:  [400, 400, 500, 500, 500, 500]  posicao:  500
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400]  posicao:  400
# passo:  44  recompensa:  291.2  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  47  recompensa:  290.6  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  195.6  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  23  recompensa:  195.4  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  24  recompensa:  195.2  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  20  recompensa:  96.0  posicoes de lata:  [400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  24  recompensa:  95.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  27  recompensa:  194.6  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  28  recompensa:  194.4  posicoes de lata:  [400, 400, 400, 400, 500, 500]  posicao:  500
# passo:  57  recompensa:  188.6  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  58  recompensa:  188.4  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  61  recompensa:  187.8  posicoes de lata:  [500, 500, 500, 500, 500, 500]  posicao:  500
# passo:  65  recompensa:  287.0  posicoes de lata:  [500, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  66  recompensa:  286.8  posicoes de lata:  [500, 500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  20  recompensa:  196.0  posicoes de lata:  [600, 600, 600, 600, 600, 500]  posicao:  500
# passo:  23  recompensa:  295.4  posicoes de lata:  [600, 600, 600, 600, 600, 500, 500, 600]  posicao:  600
# passo:  31  recompensa:  293.8  posicoes de lata:  [600, 600, 600, 600, 600, 500, 500, 600, 600]  posicao:  600
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  49  recompensa:  90.2  posicoes de lata:  [500, 400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  20  recompensa:  96.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  81  recompensa:  183.8  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  22  recompensa:  95.6  posicoes de lata:  [400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  36  recompensa:  192.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  48  recompensa:  190.4  posicoes de lata:  [600, 600, 600, 600, 600, 500]  posicao:  500
# passo:  57  recompensa:  288.6  posicoes de lata:  [600, 600, 600, 600, 600, 500, 600]  posicao:  600
# passo:  58  recompensa:  288.4  posicoes de lata:  [600, 600, 600, 600, 600, 500, 600, 600]  posicao:  600
# passo:  59  recompensa:  288.2  posicoes de lata:  [600, 600, 600, 600, 600, 500, 600, 600, 600]  posicao:  600
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  21  recompensa:  295.8  posicoes de lata:  [400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  5  recompensa:  99.0  posicoes de lata:  [400]  posicao:  400
# passo:  6  recompensa:  98.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  7  recompensa:  98.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  13  recompensa:  297.4  posicoes de lata:  [400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  14  recompensa:  297.2  posicoes de lata:  [400, 400, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  77  recompensa:  284.6  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600]  posicao:  600
# passo:  78  recompensa:  284.4  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  79  recompensa:  284.2  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  8  recompensa:  98.4  posicoes de lata:  [400]  posicao:  400
# passo:  9  recompensa:  98.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  27  recompensa:  294.6  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600]  posicao:  600
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  28  recompensa:  94.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  29  recompensa:  94.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  33  recompensa:  193.4  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  40  recompensa:  92.0  posicoes de lata:  [400]  posicao:  400
# passo:  41  recompensa:  91.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  44  recompensa:  91.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  14  recompensa:  197.2  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  15  recompensa:  197.0  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  20  recompensa:  296.0  posicoes de lata:  [400, 400, 400, 500, 500, 600, 600]  posicao:  600
# passo:  63  recompensa:  187.4  posicoes de lata:  [400, 600, 600, 500]  posicao:  500
# passo:  64  recompensa:  187.2  posicoes de lata:  [400, 600, 600, 500, 500]  posicao:  500
# passo:  65  recompensa:  187.0  posicoes de lata:  [400, 600, 600, 500, 500, 500]  posicao:  500
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  22  recompensa:  95.6  posicoes de lata:  [400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  24  recompensa:  95.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  27  recompensa:  194.6  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  28  recompensa:  194.4  posicoes de lata:  [400, 400, 400, 400, 500, 500]  posicao:  500
# passo:  20  recompensa:  96.0  posicoes de lata:  [400]  posicao:  400
# passo:  17  recompensa:  96.6  posicoes de lata:  [400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  28  recompensa:  294.4  posicoes de lata:  [400, 400, 400, 400, 400, 400, 400, 600]  posicao:  600
# passo:  32  recompensa:  293.6  posicoes de lata:  [400, 400, 400, 400, 400, 400, 400, 600, 600]  posicao:  600
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  38  recompensa:  192.4  posicoes de lata:  [400, 400, 400, 600, 600, 500]  posicao:  500
# passo:  41  recompensa:  91.8  posicoes de lata:  [400]  posicao:  400
# passo:  42  recompensa:  91.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  63  recompensa:  187.4  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  65  recompensa:  287.0  posicoes de lata:  [400, 400, 400, 400, 400, 500, 600]  posicao:  600
# passo:  69  recompensa:  286.2  posicoes de lata:  [400, 400, 400, 400, 400, 500, 600, 500, 600]  posicao:  600
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  18  recompensa:  196.4  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  19  recompensa:  196.2  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  16  recompensa:  96.8  posicoes de lata:  [400]  posicao:  400
# passo:  82  recompensa:  283.6  posicoes de lata:  [400, 400, 400, 400, 400, 400, 400, 600]  posicao:  600
# passo:  17  recompensa:  96.6  posicoes de lata:  [400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  28  recompensa:  94.4  posicoes de lata:  [400]  posicao:  400
# passo:  28  recompensa:  94.4  posicoes de lata:  [500, 500, 400]  posicao:  400
# passo:  45  recompensa:  191.0  posicoes de lata:  [500, 500, 400, 400, 400, 500]  posicao:  500
# passo:  52  recompensa:  289.6  posicoes de lata:  [500, 500, 400, 400, 400, 500, 500, 600]  posicao:  600
# passo:  53  recompensa:  289.4  posicoes de lata:  [500, 500, 400, 400, 400, 500, 500, 600, 600]  posicao:  600
# passo:  16  recompensa:  196.8  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  17  recompensa:  196.6  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  18  recompensa:  196.4  posicoes de lata:  [500, 500, 500, 500, 500, 500]  posicao:  500
# passo:  7  recompensa:  98.6  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  36  recompensa:  92.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  55  recompensa:  189.0  posicoes de lata:  [500, 500, 400, 500]  posicao:  500
# passo:  56  recompensa:  188.8  posicoes de lata:  [500, 500, 400, 500, 500]  posicao:  500
# passo:  57  recompensa:  188.6  posicoes de lata:  [500, 500, 400, 500, 500, 500]  posicao:  500
# passo:  95  recompensa:  181.0  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  96  recompensa:  180.8  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  97  recompensa:  180.6  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [500, 400]  posicao:  400
# passo:  5  recompensa:  99.0  posicoes de lata:  [400]  posicao:  400
# passo:  17  recompensa:  96.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  24  recompensa:  195.2  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  27  recompensa:  194.6  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  30  recompensa:  294.0  posicoes de lata:  [400, 400, 500, 500, 500, 600, 600]  posicao:  600
# ...
# passo:  53  recompensa:  189.4  posicoes de lata:  [400, 400, 400, 500, 500, 500]  posicao:  500
# passo:  20  recompensa:  196.0  posicoes de lata:  [500, 600, 500, 500]  posicao:  500
# passo:  21  recompensa:  195.8  posicoes de lata:  [500, 600, 500, 500, 500]  posicao:  500
# passo:  22  recompensa:  195.6  posicoes de lata:  [500, 600, 500, 500, 500, 500]  posicao:  500
# passo:  24  recompensa:  295.2  posicoes de lata:  [500, 600, 500, 500, 500, 500, 600]  posicao:  600
# passo:  8  recompensa:  98.4  posicoes de lata:  [400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400]  posicao:  400
# passo:  34  recompensa:  93.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  41  recompensa:  191.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  34  recompensa:  93.2  posicoes de lata:  [500, 400]  posicao:  400
# passo:  35  recompensa:  93.0  posicoes de lata:  [500, 400, 400]  posicao:  400
# passo:  37  recompensa:  192.6  posicoes de lata:  [500, 400, 400, 500]  posicao:  500
# passo:  38  recompensa:  192.4  posicoes de lata:  [500, 400, 400, 500, 500]  posicao:  500
# passo:  39  recompensa:  192.2  posicoes de lata:  [500, 400, 400, 500, 500, 500]  posicao:  500
# passo:  41  recompensa:  291.8  posicoes de lata:  [500, 400, 400, 500, 500, 500, 600]  posicao:  600
# passo:  25  recompensa:  95.0  posicoes de lata:  [400]  posicao:  400
# passo:  95  recompensa:  181.0  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  13  recompensa:  97.4  posicoes de lata:  [400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  39  recompensa:  192.2  posicoes de lata:  [500, 500, 500, 600, 500]  posicao:  500
# passo:  40  recompensa:  192.0  posicoes de lata:  [500, 500, 500, 600, 500, 500]  posicao:  500
# passo:  26  recompensa:  94.8  posicoes de lata:  [400]  posicao:  400
# passo:  6  recompensa:  98.8  posicoes de lata:  [400]  posicao:  400
# passo:  7  recompensa:  98.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  8  recompensa:  98.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400]  posicao:  400
# passo:  26  recompensa:  94.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  27  recompensa:  94.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  41  recompensa:  191.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  16  recompensa:  196.8  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  17  recompensa:  196.6  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  18  recompensa:  196.4  posicoes de lata:  [500, 500, 500, 500, 500, 500]  posicao:  500
# passo:  21  recompensa:  295.8  posicoes de lata:  [500, 500, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  22  recompensa:  295.6  posicoes de lata:  [500, 500, 500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  42  recompensa:  91.6  posicoes de lata:  [400]  posicao:  400
# passo:  45  recompensa:  91.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  46  recompensa:  90.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  8  recompensa:  98.4  posicoes de lata:  [400]  posicao:  400
# passo:  9  recompensa:  98.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  23  recompensa:  95.4  posicoes de lata:  [400]  posicao:  400
# passo:  46  recompensa:  90.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  47  recompensa:  90.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [400, 400]  posicao:  400
# passo:  25  recompensa:  295.0  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600]  posicao:  600
# passo:  26  recompensa:  294.8  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  27  recompensa:  294.6  posicoes de lata:  [400, 400, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  62  recompensa:  187.6  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  63  recompensa:  187.4  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  64  recompensa:  187.2  posicoes de lata:  [400, 400, 400, 500, 500, 500]  posicao:  500
# passo:  29  recompensa:  94.2  posicoes de lata:  [400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  38  recompensa:  192.4  posicoes de lata:  [400, 400, 400, 400, 500]  posicao:  500
# passo:  39  recompensa:  192.2  posicoes de lata:  [400, 400, 400, 400, 500, 500]  posicao:  500
# passo:  14  recompensa:  97.2  posicoes de lata:  [400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400]  posicao:  400
# passo:  17  recompensa:  96.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  28  recompensa:  294.4  posicoes de lata:  [400, 400, 400, 400, 400, 400, 400, 600]  posicao:  600
# passo:  29  recompensa:  294.2  posicoes de lata:  [400, 400, 400, 400, 400, 400, 400, 600, 600]  posicao:  600
# passo:  23  recompensa:  95.4  posicoes de lata:  [400]  posicao:  400
# passo:  24  recompensa:  95.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  31  recompensa:  193.8  posicoes de lata:  [400, 400, 400, 500]  posicao:  500
# passo:  32  recompensa:  193.6  posicoes de lata:  [400, 400, 400, 500, 500]  posicao:  500
# passo:  33  recompensa:  193.4  posicoes de lata:  [400, 400, 400, 500, 500, 500]  posicao:  500
# passo:  41  recompensa:  291.8  posicoes de lata:  [400, 400, 400, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  23  recompensa:  295.4  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600]  posicao:  600
# passo:  32  recompensa:  293.6  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  33  recompensa:  293.4  posicoes de lata:  [400, 400, 400, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  11  recompensa:  197.8  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  12  recompensa:  197.6  posicoes de lata:  [500, 500, 500, 500, 500]  posicao:  500
# passo:  13  recompensa:  197.4  posicoes de lata:  [500, 500, 500, 500, 500, 500]  posicao:  500
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 500, 400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400]  posicao:  400
# passo:  22  recompensa:  195.6  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  23  recompensa:  195.4  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  26  recompensa:  194.8  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  21  recompensa:  95.8  posicoes de lata:  [400]  posicao:  400
# passo:  29  recompensa:  294.2  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  32  recompensa:  293.6  posicoes de lata:  [400, 500, 600, 600, 600, 600, 600, 600]  posicao:  600
# passo:  25  recompensa:  95.0  posicoes de lata:  [400]  posicao:  400
# passo:  29  recompensa:  194.2  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  30  recompensa:  194.0  posicoes de lata:  [400, 500, 500, 500, 500]  posicao:  500
# passo:  31  recompensa:  193.8  posicoes de lata:  [400, 500, 500, 500, 500, 500]  posicao:  500
# passo:  34  recompensa:  293.2  posicoes de lata:  [400, 500, 500, 500, 500, 500, 500, 600]  posicao:  600
# passo:  35  recompensa:  293.0  posicoes de lata:  [400, 500, 500, 500, 500, 500, 500, 600, 600]  posicao:  600
# passo:  12  recompensa:  97.6  posicoes de lata:  [400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  14  recompensa:  97.2  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  24  recompensa:  95.2  posicoes de lata:  [400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  28  recompensa:  194.4  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  29  recompensa:  194.2  posicoes de lata:  [400, 400, 500, 500, 500]  posicao:  500
# passo:  30  recompensa:  194.0  posicoes de lata:  [400, 400, 500, 500, 500, 500]  posicao:  500
# passo:  15  recompensa:  97.0  posicoes de lata:  [600, 400]  posicao:  400
# passo:  16  recompensa:  96.8  posicoes de lata:  [600, 400, 400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [500, 400]  posicao:  400
# passo:  38  recompensa:  92.4  posicoes de lata:  [500, 400, 400]  posicao:  400
# passo:  25  recompensa:  195.0  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# passo:  37  recompensa:  292.6  posicoes de lata:  [500, 500, 500, 500, 600, 600, 600]  posicao:  600
# passo:  43  recompensa:  291.4  posicoes de lata:  [500, 500, 500, 500, 600, 600, 600, 600]  posicao:  600
# passo:  44  recompensa:  291.2  posicoes de lata:  [500, 500, 500, 500, 600, 600, 600, 600, 600]  posicao:  600
# passo:  14  recompensa:  97.2  posicoes de lata:  [400]  posicao:  400
# passo:  15  recompensa:  97.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  19  recompensa:  96.2  posicoes de lata:  [400]  posicao:  400
# passo:  23  recompensa:  195.4  posicoes de lata:  [400, 500, 500, 500]  posicao:  500
# passo:  23  recompensa:  95.4  posicoes de lata:  [400]  posicao:  400
# passo:  24  recompensa:  95.2  posicoes de lata:  [400, 400]  posicao:  400
# passo:  25  recompensa:  95.0  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  9  recompensa:  98.2  posicoes de lata:  [400]  posicao:  400
# passo:  10  recompensa:  98.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  11  recompensa:  97.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  7  recompensa:  98.6  posicoes de lata:  [400]  posicao:  400
# passo:  8  recompensa:  98.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  37  recompensa:  92.6  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  96  recompensa:  180.8  posicoes de lata:  [400, 400, 400, 400, 400, 500]  posicao:  500
# passo:  115  recompensa:  277.0  posicoes de lata:  [400, 400, 400, 400, 400, 500, 500, 600]  posicao:  600
# passo:  118  recompensa:  276.4  posicoes de lata:  [400, 400, 400, 400, 400, 500, 500, 600, 600]  posicao:  600
# passo:  19  recompensa:  96.2  posicoes de lata:  [400]  posicao:  400
# passo:  30  recompensa:  94.0  posicoes de lata:  [400, 400]  posicao:  400
# passo:  31  recompensa:  93.8  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  17  recompensa:  96.6  posicoes de lata:  [400]  posicao:  400
# passo:  18  recompensa:  96.4  posicoes de lata:  [400, 400]  posicao:  400
# passo:  21  recompensa:  195.8  posicoes de lata:  [400, 400, 500, 500]  posicao:  500
# passo:  11  recompensa:  97.8  posicoes de lata:  [400]  posicao:  400
# passo:  12  recompensa:  97.6  posicoes de lata:  [400, 400]  posicao:  400
# passo:  13  recompensa:  97.4  posicoes de lata:  [400, 400, 400]  posicao:  400
# passo:  22  recompensa:  295.6  posicoes de lata:  [400, 400, 400, 400, 600, 600, 600]  posicao:  600
# passo:  23  recompensa:  295.4  posicoes de lata:  [400, 400, 400, 400, 600, 600, 600, 600]  posicao:  600
# passo:  24  recompensa:  295.2  posicoes de lata:  [400, 400, 400, 400, 600, 600, 600, 600, 600]  posicao:  600
# passo:  22  recompensa:  195.6  posicoes de lata:  [500, 500, 500, 500]  posicao:  500
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6264/908050898.py in <module>
#      18 while True:
#      19     data =''
# ---> 20     data = json.loads(ws.recv())
#      21     if data['identifier']  == 'BoxConveyor_manual':
#      22         message, reward, done,step, CountCan,correctCan, ConveyorPosition, Forward, Backward, RobotCycle, StartCycle, arrayPosicoes, ToDropCan = enviroment(data, reward, done, step, CountCan, correctCan,ConveyorPosition, Forward, Backward,RobotCycle,StartCycle, arrayPosicoes, ToDropCan)
#
# ~\anaconda3\lib\site-packages\websocket\_core.py in recv(self)
#     355         """
#     356         with self.readlock:
# --> 357             opcode, data = self.recv_data()
#     358         if opcode == ABNF.OPCODE_TEXT:
#     359             return data.decode("utf-8")
#
# ~\anaconda3\lib\site-packages\websocket\_core.py in recv_data(self, control_frame)
#     378             tuple of operation code and string(byte array) value.
#     379         """
# --> 380         opcode, frame = self.recv_data_frame(control_frame)
#     381         return opcode, frame.data
#     382
#
# ~\anaconda3\lib\site-packages\websocket\_core.py in recv_data_frame(self, control_frame)
#     399         """
#     400         while True:
# --> 401             frame = self.recv_frame()
#     402             if (isEnabledForTrace()):
#     403                 trace("++Rcv raw: " + repr(frame.format()))
#
# ~\anaconda3\lib\site-packages\websocket\_core.py in recv_frame(self)
#     438         self.frame_buffer.recv_frame(): ABNF frame object
#     439         """
# --> 440         return self.frame_buffer.recv_frame()
#     441
#     442     def send_close(self, status=STATUS_NORMAL, reason=b""):
#
# ~\anaconda3\lib\site-packages\websocket\_abnf.py in recv_frame(self)
#     336             # Header
#     337             if self.has_received_header():
# --> 338                 self.recv_header()
#     339             (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     340
#
# ~\anaconda3\lib\site-packages\websocket\_abnf.py in recv_header(self)
#     292
#     293     def recv_header(self):
# --> 294         header = self.recv_strict(2)
#     295         b1 = header[0]
#     296         fin = b1 >> 7 & 1
#
# ~\anaconda3\lib\site-packages\websocket\_abnf.py in recv_strict(self, bufsize)
#     371             # buffers allocated and then shrunk, which results in
#     372             # fragmentation.
# --> 373             bytes_ = self.recv(min(16384, shortage))
#     374             self.recv_buffer.append(bytes_)
#     375             shortage -= len(bytes_)
#
# ~\anaconda3\lib\site-packages\websocket\_core.py in _recv(self, bufsize)
#     522     def _recv(self, bufsize):
#     523         try:
# --> 524             return recv(self.sock, bufsize)
#     525         except WebSocketConnectionClosedException:
#     526             if self.sock:
#
# ~\anaconda3\lib\site-packages\websocket\_socket.py in recv(sock, bufsize)
#     106             bytes_ = sock.recv(bufsize)
#     107         else:
# --> 108             bytes_ = _recv()
#     109     except TimeoutError:
#     110         raise WebSocketTimeoutException("Connection timed out")
#
# ~\anaconda3\lib\site-packages\websocket\_socket.py in _recv()
#      85     def _recv():
#      86         try:
# ---> 87             return sock.recv(bufsize)
#      88         except SSLWantReadError:
#      89             pass
#
# ConnectionResetError: [WinError 10054] Foi forçado o cancelamento de uma conexão existente pelo host remoto
